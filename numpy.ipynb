# %% [markdown]
# <a href="https://colab.research.google.com/github/shohruhinomjonov691-hub/kervan/blob/master/numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install numpy

# %%
import numpy as np

arr = np.array([1, 3, 5, 7])
print('numpy_array:', arr)
arr.shape
# Out:
# numpy_array: [1 3 5 7]
# (4,)

# %%
arr2 = np.array([[1, 3, 5, 7], [4, 6, 8, 9]])
print('numpy_array:', arr2)
arr2.shape
# Out:
# numpy_array: [[1 3 5 7]
#  [4 6 8 9]]
# (2, 4)

# %%
# dtype()
a = np.array([1, 2, 3])
print(a.dtype)
# Out:
# int64

# %%
# reshape()
a = np.array([1, 2, 3, 4, 5, 6])
b = a.reshape(2, 3)
print('shaped_array:', b)
# Out:
# shaped_array: [[1 2 3]
#  [4 5 6]]

# %%
# astype()
a = np.array([1, 2, 3])
b = a.astype(float)
print('float:', b)
# Out:
# float: [1. 2. 3.]

# %%
# np.zeros(), np.ones() => dummy data
z = np.zeros((2, 3))
o = np.ones((2, 3))

print('zeros:', z)
print('ones:', o)
# Out:
# zeros: [[0. 0. 0.]
#  [0. 0. 0.]]
# ones: [[1. 1. 1.]
#  [1. 1. 1.]]

# %%
# ndim
a = np.array([[1, 2], [3, 4] ])
print('ndim:', a.ndim)
# Out:
# ndim: 2

# %%
# arange()
a = np.arange(1, 7)
print('arange:', a)
# Out:
# arange: [1 2 3 4 5 6]

# %%
# sum(), mean(), max(), min()

a = np.array([1, 2, 3, 4])

print('sum:', a.sum())
print('mean:', a.mean())
print('max:', a.max())
print('min:', a.min())
# Out:
# sum: 10
# mean: 2.5
# max: 4
# min: 1

# %%
# flatten()

a = np.array([[1, 2], [3, 4] ])
print('flatten:', a.flatten())
# Out:
# flatten: [1 2 3 4]

# %%
# T (Transpose)
a = np.array([[1, 2], [3, 4] ])
print('transpose:', a.T)
# Out:
# transpose: [[1 3]
#  [2 4]]

# %%
# dot() @
a = np.array([[1, 2], [3, 4]])
b = np.array([[2, 0], [1, 2]])
print('dot/multiplication:', a.dot(b))
# Out:
# dot/multiplication: [[ 4  4]
#  [10  8]]

# %%
# random.rand()
a = np.random.rand(2, 3) # => 0.0 and 1.0 / 0.0 included / 1.0 excluded
print('random rand:', a)
# Out:
# random rand: [[0.38328249 0.19780864 0.47618725]
#  [0.45780804 0.02497996 0.19923523]]
